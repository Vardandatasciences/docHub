# %% [markdown]
# # OCR + AI Categorization UI Notes
#
# - Backend flow: upload-auto -> AI processing -> category update
# - Frontend: show AI status and suggestion per document, allow user to accept/change category.
